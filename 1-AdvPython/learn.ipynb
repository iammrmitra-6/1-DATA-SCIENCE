# %%
variable=10
print(type(variable))
variable="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if True:
    print("correct indentation")
    if False:
        print("this is not print")
    print("this will print")
print("outside the print block")
# Out:
# correct indentation
# this will print
# outside the print block

# %%
####simple calculator

num1= float(input("enter first number :"))
num2= float(input("enter second number :"))
sum=num1 + num2
dif =num1-num2
print("sum=",sum)
print("difference=",dif)
# Out:
# sum= 134.0
# difference= -22.0

# %%
str="hello"
print(type(str))
# Out:
# <class 'str'>

# %%
t=1
while t<2:
    print(t)
    t=t+1
# Out:
# 1

# %%
for i in range(5):
    print("shannidhya mitra")
# Out:
# shannidhya mitra
# shannidhya mitra
# shannidhya mitra
# shannidhya mitra
# shannidhya mitra

# %%
l=list(eval(input("enter a number :")))
for el in l:
    if el%2==0:
        print(el)
# Out:
# 34
# 78
# 112

# %%
print(1)
# Out:
# 1

# %%
l=list(eval(input("enter a list")))
for el in l:
    print(el)
# Out:
# 12
# 34
# 67
# 89
